# %%
import pandas as pd
import os
import json
import matplotlib.pyplot as plt
import numpy as np

# %%
csv_file = os.path.join("avg_rain_state.csv")
test_df = pd.read_csv(csv_file)

# %%
test_df
# Out:
#              State  Inches  Milli­metres  Rank
# 0          Alabama    58.3          1480     4
# 1           Alaska    22.5           572    39
# 2          Arizona    13.6           345    47
# 3         Arkansas    50.6          1284     8
# 4       California    22.2           563    40
# 5         Colorado    15.9           405    44
# 6      Connecticut    50.3          1279     9
# 7         Delaware    45.7          1160    16
# 8          Florida    54.5          1385     5
# 9          Georgia    50.7          1287     7
# 10          Hawaii    63.7          1618     1
# 11           Idaho    18.9           481    42
# 12        Illinois    39.2           996    27
# 13         Indiana    41.7          1060    26
# 14            Iowa    34.0           864    31
# 15          Kansas    28.9           733    35
# 16        Kentucky    48.9          1242    12
# 17       Louisiana    60.1          1528     2
# 18           Maine    42.2          1072    23
# ...

# %%
test_df.mean()
# Out:
# Inches           37.078
# Milli­metres    941.820
# Rank             25.480
# dtype: float64

# %%
test_df.median()
# Out:
# Inches            41.75
# Milli­metres    1061.00
# Rank              25.50
# dtype: float64

# %%
test_df.mode()
# Out:
#              State  Inches  Milli­metres  Rank
# 0          Alabama    28.9        1279.0   9.0
# 1           Alaska    42.2           NaN   NaN
# 2          Arizona    50.3           NaN   NaN
# 3         Arkansas     NaN           NaN   NaN
# 4       California     NaN           NaN   NaN
# 5         Colorado     NaN           NaN   NaN
# 6      Connecticut     NaN           NaN   NaN
# 7         Delaware     NaN           NaN   NaN
# 8          Florida     NaN           NaN   NaN
# 9          Georgia     NaN           NaN   NaN
# 10          Hawaii     NaN           NaN   NaN
# 11           Idaho     NaN           NaN   NaN
# 12        Illinois     NaN           NaN   NaN
# 13         Indiana     NaN           NaN   NaN
# 14            Iowa     NaN           NaN   NaN
# 15          Kansas     NaN           NaN   NaN
# 16        Kentucky     NaN           NaN   NaN
# 17       Louisiana     NaN           NaN   NaN
# 18           Maine     NaN           NaN   NaN
# ...

# %%
filepath = os.path.join("youtube_response.json")
with open(filepath) as jsonfile:
    video_json = json.load(jsonfile)

# %%
video_json
# Out:
# {'apiVersion': '2.0',
#  'data': {'updated': '2010-01-07T19:58:42.949Z',
#   'totalItems': 800,
#   'startIndex': 1,
#   'itemsPerPage': 1,
#   'items': [{'id': 'hYB0mn5zh2c',
#     'uploaded': '2007-06-05T22:07:03.000Z',
#     'updated': '2010-01-07T13:26:50.000Z',
#     'uploader': 'GoogleDeveloperDay',
#     'category': 'News',
#     'title': 'Google Developers Day US - Maps API Introduction',
#     'description': 'Google Maps API Introduction ...',
#     'tags': ['GDD07', 'GDD07US', 'Maps'],
#     'thumbnail': {'default': 'http://i.ytimg.com/vi/hYB0mn5zh2c/default.jpg',
#      'hqDefault': 'http://i.ytimg.com/vi/hYB0mn5zh2c/hqdefault.jpg'},
#     'player': {'default': 'http://www.youtube.com/watch?vu003dhYB0mn5zh2c'},
#     'content': {'1': 'rtsp://v5.cache3.c.youtube.com/CiILENy.../0/0/0/video.3gp',
#      '5': 'http://www.youtube.com/v/hYB0mn5zh2c?f...',
#      '6': 'rtsp://v1.cache1.c.youtube.com/CiILENy.../0/0/0/video.3gp'},
#     'duration': 2840,
# ...

# %%
csv_file = os.path.join("avg_rain_state.csv")
test_df = pd.read_csv(csv_file)

# %%
test_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
x_axis = test_df["State"]
tick_locations = [value for value in np.arange(len(test_df))]
plt.figure(figsize=(20,3))
plt.bar(x_axis,test_df["Inches"])
plt.xticks(tick_locations,test_df["State"], rotation='vertical')
plt.title("Rain in Inches by State")
plt.xlabel("State")
plt.ylabel("Rain (inches)")
plt.show()

# %%
group_df

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-d2186996bafe> in <module>
# ----> 1 group_df = group_df.to_frame().reset_index()
#
# C:\ProgramData\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     578
#     579         raise AttributeError(
# --> 580             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     581         )
#     582
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'to_frame'

# %%
students = ("Frank", "Mary", "Jasmine", "Ivana", "Ahmed")
students.append("Serena")
print(students)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-72be960c98fd> in <module>
#       1 students = ("Frank", "Mary", "Jasmine", "Ivana", "Ahmed")
# ----> 2 students.append("Serena")
#       3 print(students)
#
# AttributeError: 'tuple' object has no attribute 'append'
